# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (1.2)
# Requirement already satisfied: numpy in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from stanza) (1.19.2)
# Requirement already satisfied: requests in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from stanza) (2.24.0)
# Requirement already satisfied: protobuf in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from stanza) (3.17.1)
# Requirement already satisfied: tqdm in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from stanza) (4.50.2)
# Requirement already satisfied: torch>=1.3.0 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from stanza) (1.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from requests->stanza) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from requests->stanza) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from requests->stanza) (2.10)
# Requirement already satisfied: six>=1.9 in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: typing-extensions in /Users/usts_chen/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.3.0->stanza) (3.7.4.3)

# %%
import stanza
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 6.09MB/s]
# 2021-06-12 16:58:03 INFO: Downloading default packages for language: en (English)...
# 2021-06-12 16:58:06 INFO: File exists: /Users/usts_chen/stanza_resources/en/default.zip.
# 2021-06-12 16:58:09 INFO: Finished downloading models and saved to /Users/usts_chen/stanza_resources.

# %%
en_nlp = stanza.Pipeline('en')
# Out:
# 2021-06-12 16:58:09 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-06-12 16:58:09 INFO: Use device: cpu
# 2021-06-12 16:58:09 INFO: Loading: tokenize
# 2021-06-12 16:58:09 INFO: Loading: pos
# 2021-06-12 16:58:10 INFO: Loading: lemma
# 2021-06-12 16:58:10 INFO: Loading: depparse
# 2021-06-12 16:58:10 INFO: Loading: sentiment
# 2021-06-12 16:58:10 INFO: Loading: ner
# 2021-06-12 16:58:11 INFO: Done loading processors!

# %%
text = "This image shows the global sales of three top-selling mobile phone brands in the last five years.\
In 2013, the sales of X company reached 450 million, which were almost three times as much as the sales of Y Company.\
Even in the worst year, the sales of X Company still remained above 300 million. But after 2015, the scales of Y Company were basically stable between 200 million and 250 million.\
The scales of Z Company in 2017 were almost as good as the sales of Y Company in 2013. \
It suggests that Z company may become a strong competitor to Y Company in the mobile phone market in the near future."
doc = en_nlp(text)
print(doc)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "This",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=0|end_char=4",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "image",
#       "lemma": "image",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nsubj",
#       "misc": "start_char=5|end_char=10",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "shows",
#       "lemma": "show",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=11|end_char=16",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=17|end_char=20",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "global",
#       "lemma": "global",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=21|end_char=27",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "sales",
#       "lemma": "sale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 3,
#       "deprel": "obj",
#       "misc": "start_char=28|end_char=33",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 12,
#       "deprel": "case",
#       "misc": "start_char=34|end_char=36",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "three",
#       "lemma": "three",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 12,
#       "deprel": "nummod",
#       "misc": "start_char=37|end_char=42",
#       "ner": "S-CARDINAL"
#     },
#     {
#       "id": 9,
#       "text": "top-selling",
#       "lemma": "top-sel",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 12,
#       "deprel": "amod",
#       "misc": "start_char=43|end_char=54",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "mobile",
#       "lemma": "mobile",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 12,
#       "deprel": "amod",
#       "misc": "start_char=55|end_char=61",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "phone",
#       "lemma": "phone",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 12,
#       "deprel": "compound",
#       "misc": "start_char=62|end_char=67",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "brands",
#       "lemma": "brand",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=68|end_char=74",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 17,
#       "deprel": "case",
#       "misc": "start_char=75|end_char=77",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 17,
#       "deprel": "det",
#       "misc": "start_char=78|end_char=81",
#       "ner": "B-DATE"
#     },
#     {
#       "id": 15,
#       "text": "last",
#       "lemma": "last",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=82|end_char=86",
#       "ner": "I-DATE"
#     },
#     {
#       "id": 16,
#       "text": "five",
#       "lemma": "five",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 17,
#       "deprel": "nummod",
#       "misc": "start_char=87|end_char=91",
#       "ner": "I-DATE"
#     },
#     {
#       "id": 17,
#       "text": "years",
#       "lemma": "year",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 3,
#       "deprel": "obl",
#       "misc": "start_char=92|end_char=97",
#       "ner": "E-DATE"
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=97|end_char=98",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "In",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 2,
#       "deprel": "case",
#       "misc": "start_char=98|end_char=100",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "2013",
#       "lemma": "2013",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 9,
#       "deprel": "obl",
#       "misc": "start_char=101|end_char=105",
#       "ner": "S-DATE"
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 2,
#       "deprel": "punct",
#       "misc": "start_char=105|end_char=106",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "misc": "start_char=107|end_char=110",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "sales",
#       "lemma": "sale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 9,
#       "deprel": "nsubj",
#       "misc": "start_char=111|end_char=116",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 8,
#       "deprel": "case",
#       "misc": "start_char=117|end_char=119",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "X",
#       "lemma": "X",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "compound",
#       "misc": "start_char=120|end_char=121",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "company",
#       "lemma": "company",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "nmod",
#       "misc": "start_char=122|end_char=129",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "reached",
#       "lemma": "reach",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=130|end_char=137",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "450",
#       "lemma": "450",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 11,
#       "deprel": "nummod",
#       "misc": "start_char=138|end_char=141",
#       "ner": "B-CARDINAL"
#     },
#     {
#       "id": 11,
#       "text": "million",
#       "lemma": "million",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 9,
#       "deprel": "obj",
#       "misc": "start_char=142|end_char=149",
#       "ner": "E-CARDINAL"
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 11,
#       "deprel": "punct",
#       "misc": "start_char=149|end_char=150",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "which",
#       "lemma": "which",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "head": 19,
#       "deprel": "nsubj",
#       "misc": "start_char=151|end_char=156",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 19,
#       "deprel": "cop",
#       "misc": "start_char=157|end_char=161",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "almost",
#       "lemma": "almost",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 16,
#       "deprel": "advmod",
#       "misc": "start_char=162|end_char=168",
#       "ner": "B-CARDINAL"
#     },
#     {
#       "id": 16,
#       "text": "three",
#       "lemma": "three",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 17,
#       "deprel": "nummod",
#       "misc": "start_char=169|end_char=174",
#       "ner": "E-CARDINAL"
#     },
#     {
#       "id": 17,
#       "text": "times",
#       "lemma": "time",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 19,
#       "deprel": "obl:npmod",
#       "misc": "start_char=175|end_char=180",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 19,
#       "deprel": "advmod",
#       "misc": "start_char=181|end_char=183",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": "much",
#       "lemma": "much",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 11,
#       "deprel": "appos",
#       "misc": "start_char=184|end_char=188",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 22,
#       "deprel": "case",
#       "misc": "start_char=189|end_char=191",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 22,
#       "deprel": "det",
#       "misc": "start_char=192|end_char=195",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": "sales",
#       "lemma": "sale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 19,
#       "deprel": "obl",
#       "misc": "start_char=196|end_char=201",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 25,
#       "deprel": "case",
#       "misc": "start_char=202|end_char=204",
#       "ner": "O"
#     },
#     {
#       "id": 24,
#       "text": "Y",
#       "lemma": "Y",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 25,
#       "deprel": "compound",
#       "misc": "start_char=205|end_char=206",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 25,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 22,
#       "deprel": "nmod",
#       "misc": "start_char=207|end_char=214",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 26,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=214|end_char=215",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Even",
#       "lemma": "even",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 5,
#       "deprel": "advmod",
#       "misc": "start_char=215|end_char=219",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=220|end_char=222",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "misc": "start_char=223|end_char=226",
#       "ner": "B-DATE"
#     },
#     {
#       "id": 4,
#       "text": "worst",
#       "lemma": "worst",
#       "upos": "ADJ",
#       "xpos": "JJS",
#       "feats": "Degree=Sup",
#       "head": 5,
#       "deprel": "amod",
#       "misc": "start_char=227|end_char=232",
#       "ner": "I-DATE"
#     },
#     {
#       "id": 5,
#       "text": "year",
#       "lemma": "year",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "obl",
#       "misc": "start_char=233|end_char=237",
#       "ner": "E-DATE"
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 13,
#       "deprel": "punct",
#       "misc": "start_char=237|end_char=238",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "misc": "start_char=239|end_char=242",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "sales",
#       "lemma": "sale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 13,
#       "deprel": "nsubj",
#       "misc": "start_char=243|end_char=248",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 11,
#       "deprel": "case",
#       "misc": "start_char=249|end_char=251",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "X",
#       "lemma": "X",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 11,
#       "deprel": "compound",
#       "misc": "start_char=252|end_char=253",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 11,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "nmod",
#       "misc": "start_char=254|end_char=261",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 12,
#       "text": "still",
#       "lemma": "still",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 13,
#       "deprel": "advmod",
#       "misc": "start_char=262|end_char=267",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "remained",
#       "lemma": "remain",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=268|end_char=276",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "above",
#       "lemma": "above",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 13,
#       "deprel": "advmod",
#       "misc": "start_char=277|end_char=282",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "300",
#       "lemma": "300",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 16,
#       "deprel": "compound",
#       "misc": "start_char=283|end_char=286",
#       "ner": "B-CARDINAL"
#     },
#     {
#       "id": 16,
#       "text": "million",
#       "lemma": "million",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 13,
#       "deprel": "obj",
#       "misc": "start_char=287|end_char=294",
#       "ner": "E-CARDINAL"
#     },
#     {
#       "id": 17,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 13,
#       "deprel": "punct",
#       "misc": "start_char=294|end_char=295",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "But",
#       "lemma": "but",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 12,
#       "deprel": "cc",
#       "misc": "start_char=296|end_char=299",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "after",
#       "lemma": "after",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=300|end_char=305",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "2015",
#       "lemma": "2015",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 12,
#       "deprel": "obl",
#       "misc": "start_char=306|end_char=310",
#       "ner": "S-DATE"
#     },
#     {
#       "id": 4,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=310|end_char=311",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=312|end_char=315",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "scales",
#       "lemma": "scale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 12,
#       "deprel": "nsubj",
#       "misc": "start_char=316|end_char=322",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "case",
#       "misc": "start_char=323|end_char=325",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "Y",
#       "lemma": "Y",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 9,
#       "deprel": "compound",
#       "misc": "start_char=326|end_char=327",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 9,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=328|end_char=335",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 10,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 12,
#       "deprel": "cop",
#       "misc": "start_char=336|end_char=340",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "basically",
#       "lemma": "basically",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 12,
#       "deprel": "advmod",
#       "misc": "start_char=341|end_char=350",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "stable",
#       "lemma": "stable",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=351|end_char=357",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "between",
#       "lemma": "between",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 15,
#       "deprel": "case",
#       "misc": "start_char=358|end_char=365",
#       "ner": "B-CARDINAL"
#     },
#     {
#       "id": 14,
#       "text": "200",
#       "lemma": "200",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 15,
#       "deprel": "compound",
#       "misc": "start_char=366|end_char=369",
#       "ner": "I-CARDINAL"
#     },
#     {
#       "id": 15,
#       "text": "million",
#       "lemma": "million",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 12,
#       "deprel": "obl",
#       "misc": "start_char=370|end_char=377",
#       "ner": "I-CARDINAL"
#     },
#     {
#       "id": 16,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 18,
#       "deprel": "cc",
#       "misc": "start_char=378|end_char=381",
#       "ner": "I-CARDINAL"
#     },
#     {
#       "id": 17,
#       "text": "250",
#       "lemma": "250",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 18,
#       "deprel": "nummod",
#       "misc": "start_char=382|end_char=385",
#       "ner": "I-CARDINAL"
#     },
#     {
#       "id": 18,
#       "text": "million",
#       "lemma": "million",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 15,
#       "deprel": "conj",
#       "misc": "start_char=386|end_char=393",
#       "ner": "E-CARDINAL"
#     },
#     {
#       "id": 19,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=393|end_char=394",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "The",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=394|end_char=397",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "scales",
#       "lemma": "scale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 11,
#       "deprel": "nsubj",
#       "misc": "start_char=398|end_char=404",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=405|end_char=407",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "Z",
#       "lemma": "Z",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "compound",
#       "misc": "start_char=408|end_char=409",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 5,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=410|end_char=417",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 6,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "case",
#       "misc": "start_char=418|end_char=420",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "2017",
#       "lemma": "2017",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=421|end_char=425",
#       "ner": "S-DATE"
#     },
#     {
#       "id": 8,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 11,
#       "deprel": "cop",
#       "misc": "start_char=426|end_char=430",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "almost",
#       "lemma": "almost",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 11,
#       "deprel": "advmod",
#       "misc": "start_char=431|end_char=437",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 11,
#       "deprel": "advmod",
#       "misc": "start_char=438|end_char=440",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "good",
#       "lemma": "good",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=441|end_char=445",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 14,
#       "deprel": "case",
#       "misc": "start_char=446|end_char=448",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 14,
#       "deprel": "det",
#       "misc": "start_char=449|end_char=452",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "sales",
#       "lemma": "sale",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 11,
#       "deprel": "obl",
#       "misc": "start_char=453|end_char=458",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 17,
#       "deprel": "case",
#       "misc": "start_char=459|end_char=461",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": "Y",
#       "lemma": "Y",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 17,
#       "deprel": "compound",
#       "misc": "start_char=462|end_char=463",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 17,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 14,
#       "deprel": "nmod",
#       "misc": "start_char=464|end_char=471",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 18,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 19,
#       "deprel": "case",
#       "misc": "start_char=472|end_char=474",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": "2013",
#       "lemma": "2013",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 11,
#       "deprel": "obl",
#       "misc": "start_char=475|end_char=479",
#       "ner": "S-DATE"
#     },
#     {
#       "id": 20,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 11,
#       "deprel": "punct",
#       "misc": "start_char=479|end_char=480",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "It",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "head": 2,
#       "deprel": "nsubj",
#       "misc": "start_char=481|end_char=483",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "suggests",
#       "lemma": "suggest",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=484|end_char=492",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "mark",
#       "misc": "start_char=493|end_char=497",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "Z",
#       "lemma": "Z",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "compound",
#       "misc": "start_char=498|end_char=499",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "company",
#       "lemma": "company",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "nsubj",
#       "misc": "start_char=500|end_char=507",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "may",
#       "lemma": "may",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "head": 7,
#       "deprel": "aux",
#       "misc": "start_char=508|end_char=511",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "become",
#       "lemma": "become",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 2,
#       "deprel": "ccomp",
#       "misc": "start_char=512|end_char=518",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 10,
#       "deprel": "det",
#       "misc": "start_char=519|end_char=520",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "strong",
#       "lemma": "strong",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=521|end_char=527",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "competitor",
#       "lemma": "competitor",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "xcomp",
#       "misc": "start_char=528|end_char=538",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=539|end_char=541",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "Y",
#       "lemma": "Y",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "compound",
#       "misc": "start_char=542|end_char=543",
#       "ner": "B-ORG"
#     },
#     {
#       "id": 13,
#       "text": "Company",
#       "lemma": "Company",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=544|end_char=551",
#       "ner": "E-ORG"
#     },
#     {
#       "id": 14,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 18,
#       "deprel": "case",
#       "misc": "start_char=552|end_char=554",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 18,
#       "deprel": "det",
#       "misc": "start_char=555|end_char=558",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": "mobile",
#       "lemma": "mobile",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=559|end_char=565",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "phone",
#       "lemma": "phone",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 18,
#       "deprel": "compound",
#       "misc": "start_char=566|end_char=571",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "market",
#       "lemma": "market",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=572|end_char=578",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 22,
#       "deprel": "case",
#       "misc": "start_char=579|end_char=581",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 22,
#       "deprel": "det",
#       "misc": "start_char=582|end_char=585",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "near",
#       "lemma": "near",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 22,
#       "deprel": "amod",
#       "misc": "start_char=586|end_char=590",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": "future",
#       "lemma": "future",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "obl",
#       "misc": "start_char=591|end_char=597",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 2,
#       "deprel": "punct",
#       "misc": "start_char=597|end_char=598",
#       "ner": "O"
#     }
#   ]
# ]

# %% [markdown]
# This image shows the global sales of three top-selling mobile phone brands in the last five years.
# In 2013, the sales of X company reached 450 million, which were almost three times as much as the sales of Y Company.
# Even in the worst year, the sales of X Company still remained above 300 million.
# But after 2015, the scales of Y Company were basically stable between 200 million and 250 million.
# The scales of Z Company in 2017 were almost as good as the sales of Y Company in 2013.
# It suggests that Z company may become a strong competitor to Y Company in the mobile phone market in the near future.
#
#
# Products A and B were launched in 2008 at price points of $360+.
# They have been priced similarly over time, with B consistently slightly lower than A.
# In 2014, Products A and B were priced at $260 and $250, respectively.
# Products C, D, and E were each introduced later at much lower price points, but all have increased in price since their respective launches.
# In fact, with the launch of a new product in this space, we tend to see an initial price increase, followed by a decrease over time.
# As of 2014, retail prices have converged, with an average retail price of $223, ranging from a low of $180 (C) to a high of $260 (A).
# To be competitive, we recommend introducing our product below the $223 average price point in the $150-$200 range.

# %%
print(doc.entities)
# Out:
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 37,
#   "end_char": 42
# }, {
#   "text": "the last five years",
#   "type": "DATE",
#   "start_char": 78,
#   "end_char": 97
# }, {
#   "text": "2013",
#   "type": "DATE",
#   "start_char": 101,
#   "end_char": 105
# }, {
#   "text": "450 million",
#   "type": "CARDINAL",
#   "start_char": 138,
#   "end_char": 149
# }, {
#   "text": "almost three",
#   "type": "CARDINAL",
#   "start_char": 162,
#   "end_char": 174
# }, {
#   "text": "Y Company",
#   "type": "ORG",
#   "start_char": 205,
#   "end_char": 214
# }, {
#   "text": "the worst year",
#   "type": "DATE",
#   "start_char": 223,
#   "end_char": 237
# }, {
#   "text": "X Company",
#   "type": "ORG",
#   "start_char": 252,
#   "end_char": 261
# }, {
#   "text": "300 million",
#   "type": "CARDINAL",
#   "start_char": 283,
#   "end_char": 294
# }, {
#   "text": "2015",
#   "type": "DATE",
#   "start_char": 306,
#   "end_char": 310
# }, {
#   "text": "Y Company",
#   "type": "ORG",
#   "start_char": 326,
#   "end_char": 335
# }, {
#   "text": "between 200 million and 250 million",
#   "type": "CARDINAL",
#   "start_char": 358,
#   "end_char": 393
# }, {
#   "text": "Z Company",
#   "type": "ORG",
#   "start_char": 408,
#   "end_char": 417
# }, {
#   "text": "2017",
#   "type": "DATE",
#   "start_char": 421,
#   "end_char": 425
# }, {
#   "text": "Y Company",
#   "type": "ORG",
#   "start_char": 462,
#   "end_char": 471
# }, {
#   "text": "2013",
#   "type": "DATE",
#   "start_char": 475,
#   "end_char": 479
# }, {
#   "text": "Y Company",
#   "type": "ORG",
#   "start_char": 542,
#   "end_char": 551
# }]

# %%
print(type(doc.entities))
# Out:
# <class 'list'>

# %%
import json
#print(doc.entities[0])   
#print(type(doc.entities[0]))
list_entities = []
for i in range(len(doc.entities)):
    str_entities = str(doc.entities[i])
    json_entities = json.loads(str_entities)
    #print ("data2['text']: ", data2['text'])
    list_entity = json_entities['text']
    list_entities.append(list_entity)
#json提取对应字段，进行比较
print(list_entities)
print(type(list_entities))
# Out:
# ['three', 'the last five years', '2013', '450 million', 'almost three', 'Y Company', 'the worst year', 'X Company', '300 million', '2015', 'Y Company', 'between 200 million and 250 million', 'Z Company', '2017', 'Y Company', '2013', 'Y Company']
# <class 'list'>

# %%
json_item_list = json.dumps(list_entities, ensure_ascii=False, indent=4)
# 去除\",\\N,\n 无关符号
output_data = json_item_list.replace(r'\"','').replace(r'\\N','').replace(r'\n','')


    
print("entities:", output_data)
print(type(list_entities))
# Out:
# entities: [
#     "three",
#     "the last five years",
#     "2013",
#     "450 million",
#     "almost three",
#     "Y Company",
#     "the worst year",
#     "X Company",
#     "300 million",
#     "2015",
#     "Y Company",
#     "between 200 million and 250 million",
#     "Z Company",
#     "2017",
#     "Y Company",
#     "2013",
#     "Y Company"
# ]
# <class 'list'>

# %% [markdown]
# ## summarize categories of fact types
# #以value类为例，即句子中有数值的即返回类别value，并且这个数值是CSV文件中存在的
#
# 该任务为:输入一段话，即输出其keyword的类别
#
# 首先使用正则表达式分类句子的数字

# %%
text = ('This image shows the global sales of three top-selling mobile phone brands in the last five years.\
In 2013, the sales of X company reached 450 million, which were almost three times as much as the sales of Y Company.\
Even in the worst year, the sales of X Company still remained above 300 million. But after 2015, the scales of Y Company were basically stable between 200 million and 250 million.\
The scales of Z Company in 2017 were almost as good as the sales of Y Company in 2013. \
It suggests that Z company may become a strong competitor to Y Company in the mobile phone market in the near future.')

# %%
#将stanza识别的实体中数字取出来

judge_value = []
for i in range(len(data)):
    pattern = re.compile('[0-9]+')
    match = pattern.findall(data[i])
    if match:
        judge_value.append('value')
    else:
        judge_value.append('not value')
        
        

print(data)
print(judge_value)
# Out:
# ['This image shows the global sales of three top-selling mobile phone brands in the last five years', 'In 2013', ' the sales of X company reached 450 million', ' which were almost three times as much as the sales of Y Company', 'Even in the worst year', ' the sales of X Company still remained above 300 million', ' But after 2015', ' the scales of Y Company were basically stable between 200 million and 250 million', 'The scales of Z Company in 2017 were almost as good as the sales of Y Company in 2013', ' It suggests that Z company may become a strong competitor to Y Company in the mobile phone market in the near future']
# ['not value', 'value', 'value', 'not value', 'not value', 'value', 'value', 'value', 'value', 'not value']

# %%
#做Difference分类
#1.从txt中读取内容
#2.判断句子中是否有此类关键字
import sys

input_file = sys.argv[1]
lines_dic = ''
# 读取文件,以splitline输出可以去除换行号
with open("../examples/assets/dic/Difference.txt", "r",encoding='utf-8') as f:
    lines_dic= f.read().splitlines()
        
print(type(lines_dic))
print('Difference keywords:',lines_dic)

for i in range(len(data)):
    for j in range(len(lines_dic)):

        if lines_dic[j] in data[i]:
            #print('Yes')
            #print(i)
            judge_value[i] = "Difference"
 
print(judge_value)
# Out:
# <class 'list'>
# Difference keywords: ['is close to', 'compare', 'as much as', 'competitor', 'as good as']
# ['not value', 'value', 'value', 'Difference', 'not value', 'value', 'value', 'value', 'Difference', 'Difference']

# %%
str_data=[]

for i in range(len(data)):
    id = str(i+1)
    rows = "{id: "+id+" ,text: "+data[i]+", type:"+judge_value[i]+"}"
    str_data.append(rows)
    


json_str  = json.dumps(str_data, sort_keys=True, indent=2)
#json_str.split("\")
#tmp2 = json.loads(json_str)
print(json_str)  # 排序并且缩进两个字符输出
#print(tmp2)
# Out:
# [
#   "{id: 1 ,text: This image shows the global sales of three top-selling mobile phone brands in the last five years, type:not value}",
#   "{id: 2 ,text: In 2013, type:value}",
#   "{id: 3 ,text:  the sales of X company reached 450 million, type:value}",
#   "{id: 4 ,text:  which were almost three times as much as the sales of Y Company, type:Difference}",
#   "{id: 5 ,text: Even in the worst year, type:not value}",
#   "{id: 6 ,text:  the sales of X Company still remained above 300 million, type:value}",
#   "{id: 7 ,text:  But after 2015, type:value}",
#   "{id: 8 ,text:  the scales of Y Company were basically stable between 200 million and 250 million, type:value}",
#   "{id: 9 ,text: The scales of Z Company in 2017 were almost as good as the sales of Y Company in 2013, type:Difference}",
#   "{id: 10 ,text:  It suggests that Z company may become a strong competitor to Y Company in the mobile phone market in the near future, type:Difference}"
# ]
